# %%
from bs4 import BeautifulSoup
import requests
import pandas

# %%
response = requests.get("https://www.jumia.sn/fashion-mode/")
web=response.text
soup = BeautifulSoup(web, "html.parser")

# %%
produits=soup.find_all(name="article", class_=["prd","_fb", "col", "c-prd"])
# nom_produits=[produits[i]['data-name'] for i in range(len(produits)) ]

# %%
# ---------------           MANIPULATION
# produits[0].contents
# ----------------recuperation du nom d'un produit 
# produits[1].contents[0].get("data-name")
# ici faut noter que contet[0] contient les balise et attribut qui nous interessse
nom_produits=[produits[i].contents[0].get("data-name") for i in range(len(produits)) ]

# ----------------- recuperation du prix si y'a promo
prix_hors_promo=[produits[i].contents[0].find(name="div", class_="prc").getText() for i in range(len(produits))]

# print(produits[0].contents[0].find(name="div", class_="prc").getText())
# ---------------- recuperation du prix si y'a  promo
prix_en_promo=[produits[i].contents[0].find(name="div", class_="prc").get("data-oprc") for i in range(len(produits))]

# print(produits[0].contents[0].find(name="div", class_="prc").get("data-oprc"))
# ---------------- Recuperation pourcentage
#produits[0].contents[0].find(name="div", class_="bdg _dsct").getText()
# pourcentage=[produits[i].contents[0].find(name="div", class_="bdg _dsct").getText() for i in range(len(produits))]

# %%
frame=pandas.DataFrame(
    {'Nom':nom_produits,
     'Prix Hors Promo':prix_en_promo,
     'Prix Promo':prix_hors_promo
    })
frame
# Out:
#                                                   Nom Prix Hors Promo  \
# 0   Lot De 4 T-Shirt En Coton à Manches Courtes Po...     17 059 FCFA
# 1   Baskets à Lacets Respirants pour Hommes de Cou...      8 235 FCFA
# 2   Baskets à Lacets Respirants pour Hommes de Cou...     10 196 FCFA
# 3   Baskets à Lacets Respirants Le fool shoes pour...      5 490 FCFA
# 4                      Chaussures pour femmes- noires      5 294 FCFA
# ..                                                ...             ...
# 80                   Baskets Mode Homme + chaussettes            None
# 81                  Chemise casual rayée homme - bleu            None
# 82  Nouvelles chaussures de sport respirantes pour...            None
# 83  2 en 1 Short à manches courtes pour homme Ense...            None
# 84                        Robe Assortie Imprimée-vert            None
#
#     Prix Promo
# 0   8 700 FCFA
# 1   4 950 FCFA
# 2   7 950 FCFA
# 3   2 900 FCFA
# 4   2 700 FCFA
# ..         ...
# 80  5 900 FCFA
# 81  2 990 FCFA
# 82  2 400 FCFA
# 83  3 200 FCFA
# 84  2 320 FCFA
#
# [85 rows x 3 columns]

# %%
reponse_expat = requests.get("https://www.expat-dakar.com/mode-beaute")
web_expat=reponse_expat.text
soup_expat = BeautifulSoup(web_expat, "html.parser")

# %%
produits_expats=soup_expat.find_all(name="div", class_="listing-card")

# %%
# teste pour voir la disposition des balises
# print(soup_expat.body.div.find_all(name="a", class_="listing-card__inner")[0])
category_produit_expat=[soup_expat.body.find_all(name="a", class_="listing-card__inner")[i].get("data-t-listing_category_title") for i in range (len(produits_expat))]
prix_produit_expat=[soup_expat.body.find_all(name="a", class_="listing-card__inner")[i].get("data-t-listing_price") for i in range (len(produits_expat))]
nom_produit_expat=[soup_expat.body.find_all(name="a", class_="listing-card__inner")[i].get("data-t-listing_title") for i in range (len(produits_expat))]

# %%
nom_produit
# Out:
# ['Tondeuse HTC rechargeable',
#  'Galaxy watch 4 mémoire 16Go',
#  'Magic Plate - Block avec Plusieurs Formes pour enfant DIY',
#  'Mini Drone Mirage avec appareil photo pour enregistrement',
#  'Kangourou enfants',
#  'Transats enfants',
#  'Sécurité promenade enfants',
#  'Berceau + moustiquaire',
#  "Trotteur Bébé Multifonction+Ardoise+Lettres de l'Alphabet",
#  'Parc de jeux avec des boules pour enfants']

# %%
frame_expat=pandas.DataFrame({
    'Nom':nom_produit_expat,
     'Prix Produit':prix_produit_expat,
     'Prix Promo':''
    })
frame_expat
# Out:
#                                                  Nom Prix Produit Prix Promo
# 0                          Tondeuse HTC rechargeable     15000.00
# 1                        Galaxy watch 4 mémoire 16Go    140000.00
# 2  Magic Plate - Block avec Plusieurs Formes pour...      4000.00
# 3  Mini Drone Mirage avec appareil photo pour enr...     16900.00
# 4                                  Kangourou enfants         0.00
# 5                                   Transats enfants         0.00
# 6                         Sécurité promenade enfants         0.00
# 7                             Berceau + moustiquaire         0.00
# 8  Trotteur Bébé Multifonction+Ardoise+Lettres de...     19900.00
# 9          Parc de jeux avec des boules pour enfants     20000.00

# %%
reponse_soumari = requests.get("https://www.soumari.com/categorie-produit/informatique/")
web_soumari=reponse_soumari.text
soup_soumari = BeautifulSoup(web_soumari, "html.parser")

# %%
produit_soumari=soup_soumari.find_all( name="li", class_=["type-product","product","type-product"])

# %%
produit_soumari[0].contents
# Out:
# ['\n',
#  <div class="product-inner clearfix"><div class="mf-product-thumbnail"><a href="https://www.soumari.com/produit/imprimante-hp-officejet-6950/"><img alt="" class="attachment-woocommerce_thumbnail size-woocommerce_thumbnail" decoding="async" height="300" loading="lazy" sizes="(max-width: 300px) 100vw, 300px" src="https://www.soumari.com/wp-content/uploads/2023/03/Imprimante-HP-OFFICEJET-6950-300x300.jpg" srcset="https://www.soumari.com/wp-content/uploads/2023/03/Imprimante-HP-OFFICEJET-6950-300x300.jpg 300w, https://www.soumari.com/wp-content/uploads/2023/03/Imprimante-HP-OFFICEJET-6950-1024x1024.jpg 1024w, https://www.soumari.com/wp-content/uploads/2023/03/Imprimante-HP-OFFICEJET-6950-150x150.jpg 150w, https://www.soumari.com/wp-content/uploads/2023/03/Imprimante-HP-OFFICEJET-6950-768x768.jpg 768w, https://www.soumari.com/wp-content/uploads/2023/03/Imprimante-HP-OFFICEJET-6950-1536x1536.jpg 1536w, https://www.soumari.com/wp-content/uploads/2023/03/Imprimante-HP-OFFICEJET-6950-370x370.jpg 370w, https://www.soumari.com/wp-content/uploads/2023/03/Imprimante-HP-OFFICEJET-6950-600x600.jpg 600w, https://www.soumari.com/wp-content/uploads/2023/03/Imprimante-HP-OFFICEJET-6950-100x100.jpg 100w, https://www.soumari.com/wp-content/uploads/2023/03/Imprimante-HP-OFFICEJET-6950-50x50.jpg 50w, https://www.soumari.com/wp-content/uploads/2023/03/Imprimante-HP-OFFICEJET-6950.jpg 1600w" width="300"/><span class="ribbons"><span class="newness ribbon">New</span></span></a><div class="footer-button"><a aria-label="Ajouter “Imprimante HP OFFICEJET 6950” à votre panier" class="button wp-element-button product_type_simple add_to_cart_button ajax_add_to_cart" data-product_id="76423" data-product_sku="" data-quantity="1" data-title="Imprimante HP OFFICEJET 6950" href="?add-to-cart=76423" rel="nofollow"><i class="p-icon icon-bag2" data-rel="tooltip" title="J’ACHÈTE"></i><span class="add-to-cart-text">J’ACHÈTE</span></a><a class="mf-product-quick-view" data-id="76423" href="https://www.soumari.com/produit/imprimante-hp-officejet-6950/"><i class="p-icon icon-eye" data-rel="tooltip" title="Aperçu rapide"></i></a>
#  <div class="yith-wcwl-add-to-wishlist add-to-wishlist-76423 wishlist-fragment on-first-load" data-fragment-options='{"base_url":"","in_default_wishlist":false,"is_single":false,"show_exists":false,"product_id":76423,"parent_product_id":76423,"product_type":"simple","show_view":false,"browse_wishlist_text":false,"already_in_wishslist_text":false,"product_added_text":false,"heading_icon":"fa-heart-o","available_multi_wishlist":false,"disable_wishlist":false,"show_count":false,"ajax_loading":false,"loop_position":false,"item":"add_to_wishlist"}' data-fragment-ref="76423">
#  <!-- ADD TO WISHLIST -->
#  <div class="yith-wcwl-add-button">
#  <a class="add_to_wishlist single_add_to_wishlist" data-original-product-id="76423" data-product-id="76423" data-product-title="Imprimante HP OFFICEJET 6950" data-product-type="simple" data-rel="tooltip" href="?add_to_wishlist=76423" title="">
#  <i class="yith-wcwl-icon fa fa-heart-o"></i> <span></span>
#  </a>
#  </div>
#  <!-- COUNT TEXT -->
#  </div></div></div><div class="mf-product-details"><div class="mf-product-content"><h2 class="woo-loop-product__title"><a href="https://www.soumari.com/produit/imprimante-hp-officejet-6950/">Imprimante HP OFFICEJET 6950</a></h2><div class="woocommerce-product-details__short-description">
#  <div class="flix-std-row">
#  <div class="flix-hp-lg-12 flix-hp-xs-12 flix-pad-3px">
#  <div class="flix-hp-key-desc">Produisez des impressions couleur abordables de qualité professionnelle qui vous permettent de vous démarquer. Dynamisez votre travail avec des options d’impression mobile et une configuration mobile fluide. Bénéficiez d’une vitesse de travail impressionnante pour gérer plus de projets sans pour autant ralentir. Économisez jusqu’à 70 % sur vos cartouches d’encre grâce au service HP Instant Ink.</div>
#  </div>
#  </div>
#  </div>
#  </div><div class="mf-product-price-box">
#  <span class="price"><span class="woocommerce-Price-amount amount"><bdi>72.000 <span class="woocommerce-Price-currencySymbol">CFA</span></bdi></span></span>
#  <div class="footer-button"><a aria-label="Ajouter “Imprimante HP OFFICEJET 6950” à votre panier" class="button wp-element-button product_type_simple add_to_cart_button ajax_add_to_cart" data-product_id="76423" data-product_sku="" data-quantity="1" data-title="Imprimante HP OFFICEJET 6950" href="?add-to-cart=76423" rel="nofollow"><i class="p-icon icon-bag2" data-rel="tooltip" title="J’ACHÈTE"></i><span class="add-to-cart-text">J’ACHÈTE</span></a><div class="action-button">
#  <div class="yith-wcwl-add-to-wishlist add-to-wishlist-76423 wishlist-fragment on-first-load" data-fragment-options='{"base_url":"","in_default_wishlist":false,"is_single":false,"show_exists":false,"product_id":76423,"parent_product_id":76423,"product_type":"simple","show_view":false,"browse_wishlist_text":false,"already_in_wishslist_text":false,"product_added_text":false,"heading_icon":"fa-heart-o","available_multi_wishlist":false,"disable_wishlist":false,"show_count":false,"ajax_loading":false,"loop_position":false,"item":"add_to_wishlist"}' data-fragment-ref="76423">
#  <!-- ADD TO WISHLIST -->
#  <div class="yith-wcwl-add-button">
#  <a class="add_to_wishlist single_add_to_wishlist" data-original-product-id="76423" data-product-id="76423" data-product-title="Imprimante HP OFFICEJET 6950" data-product-type="simple" data-rel="tooltip" href="?add_to_wishlist=76423" title="">
#  <i class="yith-wcwl-icon fa fa-heart-o"></i> <span></span>
#  </a>
#  </div>
#  <!-- COUNT TEXT -->
#  </div><div class="compare-button mf-compare-button"><a class="compare" data-product_id="76423" href="https://www.soumari.com?action=yith-woocompare-add-product&amp;id=76423" title="Comparer">Comparer</a></div></div></div></div><div class="mf-product-details-hover"><h2 class="woo-loop-product__title"><a href="https://www.soumari.com/produit/imprimante-hp-officejet-6950/">Imprimante HP OFFICEJET 6950</a></h2>
#  <span class="price"><span class="woocommerce-Price-amount amount"><bdi>72.000 <span class="woocommerce-Price-currencySymbol">CFA</span></bdi></span></span>
#  </div><div class="woocommerce-product-details__short-description">
#  <div class="flix-std-row">
#  <div class="flix-hp-lg-12 flix-hp-xs-12 flix-pad-3px">
#  <div class="flix-hp-key-desc">Produisez des impressions couleur abordables de qualité professionnelle qui vous permettent de vous démarquer. Dynamisez votre travail avec des options d’impression mobile et une configuration mobile fluide. Bénéficiez d’une vitesse de travail impressionnante pour gérer plus de projets sans pour autant ralentir. Économisez jusqu’à 70 % sur vos cartouches d’encre grâce au service HP Instant Ink.</div>
#  </div>
#  </div>
#  </div>
#  <div class="gridlist-buttonwrap">
#  <script style="display:none" type="application/javascript">
#              /* <![CDATA[ */
#              window.pysWooProductData = window.pysWooProductData || [];
#              window.pysWooProductData[ 76423 ] = {"facebook":{"delay":0,"type":"static","name":"AddToCart","pixelIds":["2282230725377477"],"eventID":"8c237fb5-a5c2-40eb-9c29-add8088e4d86","params":{"content_type":"product","content_ids":["76423"],"contents":[{"id":"76423","quantity":1}],"content_name":"Imprimante HP OFFICEJET 6950","category_name":"IMPRIMANTES, INFORMATIQUE","value":72000,"currency":"XOF"},"e_id":"woo_add_to_cart_on_button_click","ids":[],"hasTimeWindow":false,"timeWindow":0,"woo_order":"","edd_order":""}};
#              /* ]]> */
#  		</script>
#  </div></div></div>]
